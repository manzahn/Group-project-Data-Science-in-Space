# %%
import pandas as pd

# --------------------------
# 1. Load the Excel file and extract the real table
# --------------------------
file_path = "UNCTAD-ISDS-Navigator-data-set-31December2023.xlsx"

# Load raw sheet with no header
raw = pd.read_excel(file_path, sheet_name="Source - UNCTAD ISDS Navigator", header=None)

# Detect header row (where first column is "NO.")
header_row_idx = raw[0].eq("NO.").idxmax()
column_names = raw.iloc[header_row_idx].tolist()

# Build cleaned dataframe
df = raw.iloc[header_row_idx + 1:].copy()
df.columns = column_names
df = df.reset_index(drop=True)

# --------------------------
# 2. Basic structural exploration
# --------------------------
print("===== FIRST 5 ROWS =====")
print(df.head(), "\n")

print("===== COLUMN NAMES =====")
print(list(df.columns), "\n")

print("===== DATAFRAME INFO =====")
print(df.info(), "\n")

print("===== SHAPE OF DATA (rows, columns) =====")
print(df.shape, "\n")

print("===== MISSING VALUES PER COLUMN =====")
print(df.isna().sum(), "\n")

# --------------------------
# 3. Simple numeric conversion for basic stats
# --------------------------
# Convert NO. and YEAR OF INITIATION to numeric (if possible)
df["NO._NUM"] = pd.to_numeric(df["NO."], errors="coerce")
df["YEAR_OF_INITIATION_NUM"] = pd.to_numeric(df["YEAR OF INITIATION"], errors="coerce")

print("===== SUMMARY STATISTICS FOR BASIC NUMERIC COLUMNS =====")
print(df[["NO._NUM", "YEAR_OF_INITIATION_NUM"]].describe(), "\n")

# --------------------------
# 4. Very simple categorical exploration
# --------------------------
print("===== TOP 10 RESPONDENT STATES =====")
print(df["RESPONDENT STATE"].value_counts().head(10), "\n")

print("===== TOP 10 HOME STATES OF INVESTOR =====")
print(df["HOME STATE OF INVESTOR"].value_counts().head(10), "\n")

print("===== TOP 10 ECONOMIC SECTORS =====")
print(df["ECONOMIC SECTOR"].value_counts().head(10), "\n")

print("===== CASES PER YEAR (sorted) =====")
print(df["YEAR OF INITIATION"].value_counts().sort_index(), "\n")
# Out:
# ===== FIRST 5 ROWS =====
#   NO. YEAR OF INITIATION              SHORT CASE NAME  \
# 0   1               2023    Abertis v. Argentina (II)
# 1   2               2023             Access v. Mexico
# 2   3               2023               AET v. Germany
# 3   4               2023   Amadeus v. North Macedonia
# 4   5               2023  Ambiente v. North Macedonia
#
#                                       FULL CASE NAME  \
# 0  Abertis Infraestructuras, S.A. v. Argentine Re...
# 1  Access Business Group LLC v. United Mexican St...
# 2  Azienda Elettrica Ticinese v. Federal Republic...
# 3  Amadeus Group and Amadeus Development DOOEL v....
# 4  FCL Ambiente S.r.l. v. Republic of North Maced...
#
#                                       APPLICABLE IIA  \
# 0                       Argentina - Spain BIT (1991)
# 1                        NAFTA (1992);\nUSMCA (2018)
# 2                   The Energy Charter Treaty (1994)
# 3  Albania - Macedonia, The former Yugoslav Repub...
# 4  Italy - Macedonia, The former Yugoslav Republi...
#
#                                       ARBITRAL RULES  \
# 0  ICSID (International Centre for Settlement of ...
# 1  ICSID (International Centre for Settlement of ...
# 2  ICSID (International Centre for Settlement of ...
# 3  ICSID (International Centre for Settlement of ...
# 4  ICSID (International Centre for Settlement of ...
#
#                            ADMINISTERING INSTITUTION  \
# 0  ICSID (International Centre for Settlement of ...
# 1  ICSID (International Centre for Settlement of ...
# 2  ICSID (International Centre for Settlement of ...
# 3  ICSID (International Centre for Settlement of ...
# 4  ICSID (International Centre for Settlement of ...
#
#   STATUS/OUTCOME OF ORIGINAL PROCEEDINGS RESPONDENT STATE  \
# 0                                Pending        Argentina
# 1                                Pending           Mexico
# 2                                Pending          Germany
# 3                                Pending  North Macedonia
# 4                                Pending  North Macedonia
#
#      HOME STATE OF INVESTOR  ...  \
# 0                     Spain  ...
# 1  United States of America  ...
# 2               Switzerland  ...
# 3                   Albania  ...
# 4                     Italy  ...
#
#   AMOUNT AWARDED (OR SETTLED FOR) (EXPRESSED IN MILLIONS)  \
# 0                                 Data not available
# 1                                 Data not available
# 2                                 Data not available
# 3                                 Data not available
# 4                                 Data not available
#
#                                 IIA BREACHES ALLEGED IIA BREACHES FOUND  \
# 0                                 Data not available            Pending
# 1  Fair and equitable treatment/Minimum standard ...            Pending
# 2                                 Data not available            Pending
# 3  Fair and equitable treatment/Minimum standard ...            Pending
# 4                                 Data not available            Pending
#
#   FOLLOW-ON PROCEEDING TYPE FOLLOW-ON PROCEEDING STATUS FOLLOW-ON DECISIONS  \
# 0                       NaN                         NaN                 NaN
# 1                       NaN                         NaN                 NaN
# 2                       NaN                         NaN                 NaN
# 3                       NaN                         NaN                 NaN
# 4                       NaN                         NaN                 NaN
#
#         FOLLOW-ON INDIVIDUAL OPINIONS ICSID ANNULMENT COMMITTEE MEMBERS  \
# 0  No follow-up proceedings initiated                               NaN
# 1  No follow-up proceedings initiated                               NaN
# 2  No follow-up proceedings initiated                               NaN
# 3  No follow-up proceedings initiated                               NaN
# 4  No follow-up proceedings initiated                               NaN
#
#            LINK TO ITALAW'S CASE PAGE  \
# 0                       Not available
# 1  https://www.italaw.com/cases/10529
# 2                       Not available
# 3  https://www.italaw.com/cases/10730
# 4                       Not available
#
#                          LINKS TO BACKGROUND SOURCES
# 0  https://icsid.worldbank.org/cases/case-databas...
# 1  https://icsid.worldbank.org/cases/case-databas...
# 2  https://icsid.worldbank.org/cases/case-databas...
# 3  https://icsid.worldbank.org/cases/case-databas...
# 4  https://icsid.worldbank.org/cases/case-databas...
#
# [5 rows x 28 columns]
#
# ===== COLUMN NAMES =====
# ['NO.', 'YEAR OF INITIATION', 'SHORT CASE NAME', 'FULL CASE NAME', 'APPLICABLE IIA', 'ARBITRAL RULES', 'ADMINISTERING INSTITUTION', 'STATUS/OUTCOME OF ORIGINAL PROCEEDINGS', 'RESPONDENT STATE', 'HOME STATE OF INVESTOR', 'ECONOMIC SECTOR', 'ECONOMIC SUBSECTOR', 'SUMMARY OF THE DISPUTE', ' DETAILS OF INVESTMENT', 'ARBITRATORS', 'DECISIONS', 'INDIVIDUAL OPINIONS DETAILS', 'AMOUNT CLAIMED (EXPRESSED IN MILLIONS)', 'AMOUNT AWARDED (OR SETTLED FOR) (EXPRESSED IN MILLIONS)', 'IIA BREACHES ALLEGED', 'IIA BREACHES FOUND', 'FOLLOW-ON PROCEEDING TYPE', 'FOLLOW-ON PROCEEDING STATUS', 'FOLLOW-ON DECISIONS', 'FOLLOW-ON INDIVIDUAL OPINIONS', 'ICSID ANNULMENT COMMITTEE MEMBERS', "LINK TO ITALAW'S CASE PAGE", 'LINKS TO BACKGROUND SOURCES']
#
# ===== DATAFRAME INFO =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   NO.                                                      1332 non-null   object
#  1   YEAR OF INITIATION                                       1332 non-null   object
#  2   SHORT CASE NAME                                          1332 non-null   object
#  3   FULL CASE NAME                                           1332 non-null   object
#  4   APPLICABLE IIA                                           1332 non-null   object
#  5   ARBITRAL RULES                                           1332 non-null   object
#  6   ADMINISTERING INSTITUTION                                1332 non-null   object
#  7   STATUS/OUTCOME OF ORIGINAL PROCEEDINGS                   1332 non-null   object
#  8   RESPONDENT STATE                                         1332 non-null   object
#  9   HOME STATE OF INVESTOR                                   1332 non-null   object
#  10  ECONOMIC SECTOR                                          1332 non-null   object
#  11  ECONOMIC SUBSECTOR                                       1332 non-null   object
#  12  SUMMARY OF THE DISPUTE                                   1119 non-null   object
#  13   DETAILS OF INVESTMENT                                   1154 non-null   object
#  14  ARBITRATORS                                              1331 non-null   object
#  15  DECISIONS                                                1210 non-null   object
#  16  INDIVIDUAL OPINIONS DETAILS                              599 non-null    object
#  17  AMOUNT CLAIMED (EXPRESSED IN MILLIONS)                   1327 non-null   object
#  18  AMOUNT AWARDED (OR SETTLED FOR) (EXPRESSED IN MILLIONS)  1198 non-null   object
#  19  IIA BREACHES ALLEGED                                     1332 non-null   object
#  20  IIA BREACHES FOUND                                       1332 non-null   object
#  21  FOLLOW-ON PROCEEDING TYPE                                311 non-null    object
#  22  FOLLOW-ON PROCEEDING STATUS                              311 non-null    object
#  23  FOLLOW-ON DECISIONS                                      251 non-null    object
#  24  FOLLOW-ON INDIVIDUAL OPINIONS                            1085 non-null   object
#  25  ICSID ANNULMENT COMMITTEE MEMBERS                        181 non-null    object
#  26  LINK TO ITALAW'S CASE PAGE                               1332 non-null   object
#  27  LINKS TO BACKGROUND SOURCES                              1320 non-null   object
# dtypes: object(28)
# memory usage: 291.5+ KB
# None
#
# ===== SHAPE OF DATA (rows, columns) =====
# (1332, 28)
#
# ===== MISSING VALUES PER COLUMN =====
# NO.                                                           0
# YEAR OF INITIATION                                            0
# SHORT CASE NAME                                               0
# FULL CASE NAME                                                0
# APPLICABLE IIA                                                0
# ARBITRAL RULES                                                0
# ADMINISTERING INSTITUTION                                     0
# STATUS/OUTCOME OF ORIGINAL PROCEEDINGS                        0
# RESPONDENT STATE                                              0
# HOME STATE OF INVESTOR                                        0
# ECONOMIC SECTOR                                               0
# ECONOMIC SUBSECTOR                                            0
# SUMMARY OF THE DISPUTE                                      213
#  DETAILS OF INVESTMENT                                      178
# ARBITRATORS                                                   1
# DECISIONS                                                   122
# INDIVIDUAL OPINIONS DETAILS                                 733
# AMOUNT CLAIMED (EXPRESSED IN MILLIONS)                        5
# AMOUNT AWARDED (OR SETTLED FOR) (EXPRESSED IN MILLIONS)     134
# IIA BREACHES ALLEGED                                          0
# IIA BREACHES FOUND                                            0
# FOLLOW-ON PROCEEDING TYPE                                  1021
# FOLLOW-ON PROCEEDING STATUS                                1021
# FOLLOW-ON DECISIONS                                        1081
# FOLLOW-ON INDIVIDUAL OPINIONS                               247
# ICSID ANNULMENT COMMITTEE MEMBERS                          1151
# LINK TO ITALAW'S CASE PAGE                                    0
# LINKS TO BACKGROUND SOURCES                                  12
# dtype: int64
#
# ===== SUMMARY STATISTICS FOR BASIC NUMERIC COLUMNS =====
#           NO._NUM  YEAR_OF_INITIATION_NUM
# count  1332.00000             1332.000000
# mean    666.50000             2013.313063
# std     384.65959                6.752491
# min       1.00000             1987.000000
# 25%     333.75000             2008.750000
# 50%     666.50000             2015.000000
# 75%     999.25000             2019.000000
# max    1332.00000             2023.000000
#
# ===== TOP 10 RESPONDENT STATES =====
# RESPONDENT STATE
# Argentina                            65
# Venezuela, Bolivarian Republic of    64
# Spain                                56
# Mexico                               52
# Egypt                                46
# Czechia                              42
# Poland                               37
# Peru                                 34
# Canada                               34
# Ukraine                              31
# Name: count, dtype: int64
#
# ===== TOP 10 HOME STATES OF INVESTOR =====
# HOME STATE OF INVESTOR
# United States of America    216
# Netherlands                 106
# United Kingdom               89
# Germany                      69
# Spain                        66
# Canada                       59
# France                       58
# Türkiye                      48
# Italy                        46
# Switzerland                  42
# Name: count, dtype: int64
#
# ===== TOP 10 ECONOMIC SECTORS =====
# ECONOMIC SECTOR
# Tertiary - D - Electricity, gas, steam and air conditioning supply                    220
# Primary - B - Mining and quarrying                                                    197
# Secondary - C - Manufacturing                                                         167
# Tertiary - F - Construction                                                           130
# Tertiary - K - Financial and insurance activities                                     128
# Tertiary - J - Information and communication                                           93
# Tertiary - L - Real estate activities                                                  61
# Tertiary - H - Transportation and storage                                              55
# Primary - A - Agriculture, forestry and fishing                                        39
# Tertiary - E - Water supply; sewerage, waste management and remediation activities     36
# Name: count, dtype: int64
#
# ===== CASES PER YEAR (sorted) =====
# YEAR OF INITIATION
# 1987     1
# 1993     1
# 1994     2
# 1995     2
# 1996     6
# 1997     7
# 1998    11
# 1999    14
# 2000    13
# 2001    17
# 2002    26
# 2003    40
# 2004    42
# 2005    40
# 2006    27
# 2007    45
# 2008    39
# 2009    41
# 2010    36
# 2011    54
# 2012    56
# 2013    71
# 2014    60
# 2015    85
# 2016    78
# 2017    85
# 2018    93
# 2019    65
# 2020    79
# 2021    77
# 2022    59
# 2023    60
# Name: count, dtype: int64

# %%
print("===== DATAFRAME INFO =====")
print(df.info(), "\n")

print("===== SHAPE OF DATA (rows, columns) =====")
print(df.shape, "\n")
# Out:
# ===== DATAFRAME INFO =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 30 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   NO.                                                      1332 non-null   object
#  1   YEAR OF INITIATION                                       1332 non-null   object
#  2   SHORT CASE NAME                                          1332 non-null   object
#  3   FULL CASE NAME                                           1332 non-null   object
#  4   APPLICABLE IIA                                           1332 non-null   object
#  5   ARBITRAL RULES                                           1332 non-null   object
#  6   ADMINISTERING INSTITUTION                                1332 non-null   object
#  7   STATUS/OUTCOME OF ORIGINAL PROCEEDINGS                   1332 non-null   object
#  8   RESPONDENT STATE                                         1332 non-null   object
#  9   HOME STATE OF INVESTOR                                   1332 non-null   object
#  10  ECONOMIC SECTOR                                          1332 non-null   object
#  11  ECONOMIC SUBSECTOR                                       1332 non-null   object
#  12  SUMMARY OF THE DISPUTE                                   1119 non-null   object
#  13   DETAILS OF INVESTMENT                                   1154 non-null   object
#  14  ARBITRATORS                                              1331 non-null   object
#  15  DECISIONS                                                1210 non-null   object
#  16  INDIVIDUAL OPINIONS DETAILS                              599 non-null    object
#  17  AMOUNT CLAIMED (EXPRESSED IN MILLIONS)                   1327 non-null   object
#  18  AMOUNT AWARDED (OR SETTLED FOR) (EXPRESSED IN MILLIONS)  1198 non-null   object
#  19  IIA BREACHES ALLEGED                                     1332 non-null   object
#  20  IIA BREACHES FOUND                                       1332 non-null   object
#  21  FOLLOW-ON PROCEEDING TYPE                                311 non-null    object
#  22  FOLLOW-ON PROCEEDING STATUS                              311 non-null    object
#  23  FOLLOW-ON DECISIONS                                      251 non-null    object
#  24  FOLLOW-ON INDIVIDUAL OPINIONS                            1085 non-null   object
#  25  ICSID ANNULMENT COMMITTEE MEMBERS                        181 non-null    object
#  26  LINK TO ITALAW'S CASE PAGE                               1332 non-null   object
#  27  LINKS TO BACKGROUND SOURCES                              1320 non-null   object
#  28  NO._NUM                                                  1332 non-null   int64
#  29  YEAR_OF_INITIATION_NUM                                   1332 non-null   int64
# dtypes: int64(2), object(28)
# memory usage: 312.3+ KB
# None
#
# ===== SHAPE OF DATA (rows, columns) =====
# (1332, 30)
