# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import numpy as np  # This is for general numerical operations
import seaborn as sns  # This allows us to efficiently and beautifully plot
import os
import geopandas as gpd
import palettable as pltt
from seaborn import palplot

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df_deals = pd.read_csv(
    "export\deals.csv",
    sep=";",          # semicolon-separated
    engine="python",  # needed for multiline fields
    encoding="utf-8",
)

df_deals.head()
# df_deals.info()
# Out:
#    Deal ID Is public     Deal scope  Deal size Target country  \
# 0      710       Yes  transnational    15000.0      Argentina
# 1      717       Yes  transnational    24394.0      Argentina
# 2      724       Yes  transnational    14000.0      Argentina
# 3      727       Yes  transnational   468000.0      Argentina
# 4      729       Yes  transnational    11000.0      Argentina
#
#    Current size under contract  Current size in operation (production)  \
# 0                      15000.0                                     NaN
# 1                      24394.0                                     NaN
# 2                      14000.0                                 14000.0
# 3                     468000.0                                468000.0
# 4                      11000.0                                 11000.0
#
#     Current negotiation status  Current implementation status  \
# 0  Concluded (Contract signed)  Startup phase (no production)
# 1  Concluded (Contract signed)            Project not started
# 2  Concluded (Contract signed)      In operation (production)
# 3  Concluded (Contract signed)      In operation (production)
# 4  Concluded (Contract signed)      In operation (production)
#
#                       Fully updated                 Created at  \
# 0  2023-07-01T15:49:22.403000+00:00  2013-02-15T16:00:33+00:00
# 1  2023-07-01T19:15:17.111000+00:00  2013-02-15T16:00:34+00:00
# 2  2023-07-02T23:17:16.115000+00:00  2013-02-15T16:00:34+00:00
# 3  2023-07-03T22:20:20.959000+00:00  2013-02-15T16:00:35+00:00
# 4  2024-05-07T14:59:33.828000+00:00  2013-02-15T16:00:35+00:00
#
#                                 Top parent companies  Intended size (in ha)  \
# 0  Joseph Lewis#3986#United Kingdom of Great Brit...                    NaN
# 1                           Grupo Burco#4071#Belgium                    NaN
# 2  AgroGeneration#656#France|La Suerte Agro SA#37...                50000.0
# 3                             Walbrook#3987#Malaysia                    NaN
# 4                             Sojitz Group#526#Japan               200000.0
#
#   Size under contract (leased or purchased area, in ha)  \
# 0                                 2006#current#15000
# 1  2006##7080|2007##11580|2010##14270|2011#curren...
# 2                                 2012#current#14000
# 3                                2011#current#468000
# 4                                 2010#current#11000
#
#   Size in operation (production, in ha)  \
# 0                                   NaN
# 1                                   NaN
# 2                    2012#current#14000
# 3                   2011#current#468000
# 4                    2012#current#11000
#
#                                 Comment on land area  \
# 0  The same source saids that Joe Lewis already o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#          Intention of investment Comment on intention of investment  \
# 0              #current##Tourism                                NaN
# 1              #current##Tourism                                NaN
# 2           #current##Food crops                                NaN
# 3  #current##Food crops, Tourism                                NaN
# 4  2012#current#11000#Food crops                                NaN
#
#   Carbon offset project Comment on carbon offset project Nature of the deal  \
# 0               Unknown                              NaN  Outright purchase
# 1               Unknown                              NaN  Outright purchase
# 2               Unknown                              NaN              Lease
# 3               Unknown                              NaN  Outright purchase
# 4               Unknown                              NaN              Lease
#
#   Comment on nature of the deal                        Negotiation status  \
# 0                           NaN  2006#current#Concluded (Contract signed)
# 1                           NaN  2008#current#Concluded (Contract signed)
# 2                           NaN  2012#current#Concluded (Contract signed)
# 3                           NaN  2001#current#Concluded (Contract signed)
# 4                           NaN  2010#current#Concluded (Contract signed)
#
#                        Comment on negotiation status  \
# 0  Construction of a supposed luxurious tourism c...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                         Implementation status  \
# 0  2006#current#Startup phase (no production)
# 1            2013#current#Project not started
# 2      2010#current#In operation (production)
# 3      2001#current#In operation (production)
# 4      2012#current#In operation (production)
#
#                     Comment on implementation status  Purchase price  \
# 0  Construction of a supposed luxurious tourism c...             NaN
# 1        No information on implementation status (4)             NaN
# 2                                                NaN             NaN
# 3                                                NaN       5000000.0
# 4  In Argentina, now in its third year, we will s...             NaN
#
#   Purchase price currency Purchase price area type  Purchase price area  \
# 0                     NaN                      NaN                  NaN
# 1                     NaN                      NaN                  NaN
# 2                     NaN                      NaN                  NaN
# 3           US Dollar ($)                      NaN                  NaN
# 4                     NaN                      NaN                  NaN
#
#                            Comment on purchase price  Annual leasing fee  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  La empresa pagó 5 millones de dólares por las ...                 NaN
# 4                                                NaN                 NaN
#
#   Annual leasing fee currency Annual leasing fee type  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#    Annual leasing fee area Comment on leasing fees Contract farming  \
# 0                      NaN                     NaN          Unknown
# 1                      NaN                     NaN          Unknown
# 2                      NaN                     NaN          Unknown
# 3                      NaN                     NaN          Unknown
# 4                      NaN                     NaN          Unknown
#
#   On leased / purchased On leased area/farmers/households  \
# 0               Unknown                               NaN
# 1               Unknown                               NaN
# 2               Unknown                               NaN
# 3               Unknown                               NaN
# 4               Unknown                               NaN
#
#   Not on leased / purchased (out-grower)  \
# 0                                Unknown
# 1                                Unknown
# 2                                Unknown
# 3                                Unknown
# 4                                Unknown
#
#   Not on leased area/farmers/households (out-grower)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Comment on contract farming Jobs created (total)  \
# 0                         NaN              Unknown
# 1                         NaN              Unknown
# 2                         NaN                  Yes
# 3                         NaN                  Yes
# 4                         NaN              Unknown
#
#    Planned number of jobs (total)  Planned employees (total)  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                           200.0                        NaN
# 4                             NaN                        NaN
#
#    Planned daily/seasonal workers (total)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Current total number of jobs/employees/ daily/seasonal workers  \
# 0                                                NaN
# 1                                                NaN
# 2                                 2012#current##200#
# 3                                                NaN
# 4                                                NaN
#
#                      Comment on jobs created (total) Jobs created (foreign)  \
# 0                                                NaN                Unknown
# 1                                                NaN                Unknown
# 2  corresponde a todos los empleados de la empres...                Unknown
# 3  En sus inicios, la empresa planeaba crear 200 ...                Unknown
# 4                                                NaN                Unknown
#
#    Planned number of jobs (foreign)  Planned employees (foreign)  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    Planned daily/seasonal workers (foreign)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Current foreign number of jobs/employees/ daily/seasonal workers  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Comment on jobs created (foreign) Jobs created (domestic)  \
# 0                               NaN                 Unknown
# 1                               NaN                 Unknown
# 2                               NaN                 Unknown
# 3                               NaN                 Unknown
# 4                               NaN                 Unknown
#
#    Planned number of jobs (domestic)  Planned employees (domestic)  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Planned daily/seasonal workers (domestic)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Current domestic number of jobs/employees/ daily/seasonal workers  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Comment on jobs created (domestic)  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   Actors involved in the negotiation / admission process  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Name of investment project  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                          Comment on investment chain  \
# 0  According to source 1, Joe Lewis and his son C...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Operating company: Investor ID            Operating company: Name  \
# 0                           35355                   Hidden Lake S.A.
# 1                           35361                Burco Argentina SA.
# 2                           35367                    AgerAustral S.A
# 3                           35369              Nieves de Mendoza SA.
# 4                           35370  Sojitz Buenas Tierras del Sur SA.
#
#   Operating company: Country of registration/origin  \
# 0                                         Argentina
# 1                                         Argentina
# 2                                           Ukraine
# 3                                         Argentina
# 4                                         Argentina
#
#   Operating company: Classification Operating company: Investor homepage  \
# 0                   Private company                                  NaN
# 1                   Private company                                  NaN
# 2                   Private company                                  NaN
# 3                   Private company                                  NaN
# 4                   Private company                                  NaN
#
#   Operating company: Opencorporates link Operating company: Comment  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#   Name of community Name of indigenous people  \
# 0               NaN                       NaN
# 1               NaN                       NaN
# 2               NaN                       NaN
# 3               NaN                       NaN
# 4               NaN                       NaN
#
#   Comment on communities / indigenous peoples affected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Recognition status of community land tenure  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Comment on recognitions status of community land tenure  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Community consultation Comment on consultation of local community  \
# 0          Not consulted                                        NaN
# 1                    NaN                                        NaN
# 2                    NaN                                        NaN
# 3                    NaN                                        NaN
# 4                    NaN                                        NaN
#
#   Community reaction Comment on community reaction Presence of land conflicts  \
# 0     Mixed reaction                           NaN                    Unknown
# 1                NaN                           NaN                    Unknown
# 2                NaN                           NaN                    Unknown
# 3                NaN                           NaN                        Yes
# 4                NaN                           NaN                    Unknown
#
#                Comment on presence of land conflicts Displacement of people  \
# 0                                                NaN                Unknown
# 1                                                NaN                Unknown
# 2                                                NaN                Unknown
# 3  La familia Gutiérrez de puesto “El álamo” resi...                Unknown
# 4                                                NaN                Unknown
#
#    Number of people actually displaced  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Number of households actually displaced  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Number of people displaced out of their community land  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of people displaced staying on community land  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of households displaced "only" from their agricultural fields  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of people facing displacement once project is fully implemented  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                    Comment on displacement of people  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The town Las Juntas is in the lands purchased ...
# 4                                                NaN
#
#   Negative impacts for local communities  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Comment on negative impacts for local communities  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Promised compensation (e.g. for damages or resettlements)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Received compensation (e.g. for damages or resettlements)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Promised benefits for local communities  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Comment on promised benefits for local communities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Materialized benefits for local communities  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Comment on materialized benefits for local communities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Presence of organizations and actions taken (e.g. farmer organizations, NGOs, etc.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Former land owner Comment on former land owner Former land use  \
# 0               NaN                          NaN             NaN
# 1               NaN                          NaN             NaN
# 2               NaN                          NaN             NaN
# 3               NaN                          NaN             NaN
# 4               NaN                          NaN             NaN
#
#   Comment on former land use Former land cover Comment on former land cover  \
# 0                        NaN               NaN                          NaN
# 1                        NaN               NaN                          NaN
# 2                        NaN               NaN                          NaN
# 3                        NaN               NaN                          NaN
# 4                        NaN               NaN                          NaN
#
#                              Crops area/yield/export  \
# 0                                                NaN
# 1                                                NaN
# 2                  #current####Cereals (unspecified)
# 3  #current####Potatoes, Seeds Production (unspec...
# 4        #current####Corn (Maize), Soya Beans, Wheat
#
#                                     Comment on crops  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Production of 30,000 tons of soybeans and grai...
#
#   Livestock area/yield/export Comment on livestock  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3           #current####Goats                  NaN
# 4                         NaN                  NaN
#
#   Mineral resources area/yield/export Comment on mineral resources  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#   Contract farming crops  Comment on contract farming crops  \
# 0                    NaN                                NaN
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
#
#    Contract farming livestock  Comment on contract farming livestock  \
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
#
#   Electricity generation Comment on electricity generation  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#   Carbon sequestration/offsetting Comment on carbon sequestration/offsetting  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
#
#   Has domestic use  Domestic use Has export  Export Country 1  \
# 0          Unknown           NaN    Unknown     NaN       NaN
# 1          Unknown           NaN    Unknown     NaN       NaN
# 2          Unknown           NaN    Unknown     NaN       NaN
# 3          Unknown           NaN        Yes     NaN     India
# 4          Unknown           NaN        Yes     NaN     Japan
#
#    Country 1 ratio Country 2  Country 2 ratio Country 3  Country 3 ratio  \
# 0              NaN       NaN              NaN       NaN              NaN
# 1              NaN       NaN              NaN       NaN              NaN
# 2              NaN       NaN              NaN       NaN              NaN
# 3              NaN       NaN              NaN       NaN              NaN
# 4              NaN       NaN              NaN       NaN              NaN
#
#   Comment on use of produce In country processing of produce  \
# 0                       NaN                          Unknown
# 1                       NaN                          Unknown
# 2                       NaN                          Unknown
# 3                       NaN                          Unknown
# 4                       NaN                          Unknown
#
#   Comment on in country processing of produce  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4    FOD (Food processing (no specification))
#
#   Processing facilities / production infrastructure of the project (e.g. oil mill, ethanol distillery, biomass power plant etc.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   In-country end products of the project Water extraction envisaged  \
# 0                                    NaN                    Unknown
# 1                                    NaN                    Unknown
# 2                                    NaN                    Unknown
# 3                                    NaN                    Unknown
# 4                                    NaN                    Unknown
#
#   Comment on water extraction envisaged Source of water extraction  \
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
# 3                                   NaN                        NaN
# 4                                   NaN                        NaN
#
#   Comment on source of water extraction  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Comment on how much do investors pay for water  Water extraction amount  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4                                            NaN                      NaN
#
#   Comment on how much water is extracted Use of irrigation infrastructure  \
# 0                                    NaN                          Unknown
# 1                                    NaN                          Unknown
# 2                                    NaN                          Unknown
# 3                                    NaN                          Unknown
# 4                                    NaN                          Unknown
#
#   Comment on use of irrigation infrastructure  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Water footprint of the investment project Comment on gender-related info  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#                                      Overall comment  Not public  \
# 0  Import of error check - Coordinator's overview...       False
# 1                                                NaN       False
# 2        This was a trial for further big investment       False
# 3  Import of error check - Coordinator's overview...       False
# 4                                                NaN       False
#
#    Comment on not public
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
#getting number of deals made per country
df_deals.groupby(['Target country'], group_keys = True)[['Deal ID']].count()
# Out:
#                 Deal ID
# Target country
# Argentina            65
# Belize                4
# Bolivia               5
# Brazil              140
# Chile                54
# Colombia             28
# Costa Rica            3
# Cuba                  2
# Ecuador               1
# Guatemala             4
# Guyana                6
# Honduras              2
# Jamaica               1
# Mexico               14
# Nicaragua            17
# Panama                2
# Paraguay             13
# Peru                 19
# Suriname              1
# Uruguay              53
# Venezuela, RB         1

# %%
#To look at how the Intention of investment column is structured (and subsequently filter by sector)
investment_sector = df_deals['Intention of investment']
investment_sector.head()
# Out:
# 0                #current##Tourism
# 1                #current##Tourism
# 2             #current##Food crops
# 3    #current##Food crops, Tourism
# 4    2012#current#11000#Food crops
# Name: Intention of investment, dtype: object

# %%
Tourism = df_deals[df_deals['Intention of investment'].str.contains('Tourism')]
len(Tourism)
# Out:
# 11

# %%
Conservation = df_deals[df_deals['Intention of investment'].str.contains('Conservation')]
len(Conservation)
# Out:
# 15

# %%
Food_crops = df_deals[df_deals['Intention of investment'].str.contains('Food' or 'crops' or 'Agriculture')]
len(Food_crops)
# Out:
# 180

# %%
Livestock = df_deals[df_deals['Intention of investment'].str.contains('Livestock')]
len(Livestock)
# Out:
# 75

# %%
Timber = df_deals[df_deals['Intention of investment'].str.contains('Timber')]
len(Timber)
# Out:
# 89

# %%
Biofuels = df_deals[df_deals['Intention of investment'].str.contains('biofuels')]
len(Biofuels)
# Out:
# 50

# %%
Wind_energy = df_deals[df_deals['Intention of investment'].str.contains('Wind')]
len(Wind_energy)
# Out:
# 47

# %%
Solar_energy = df_deals[df_deals['Intention of investment'].str.contains('Solar')]
len(Solar_energy)
# Out:
# 16

# %%
Other_energy = df_deals[df_deals['Intention of investment'].str.contains('Renewable')]
len(Other_energy)
# Out:
# 12

# %%
print(df_deals.isna().sum(), '\n')
# Out:
# Deal ID                                                                                                                             0
# Is public                                                                                                                           0
# Deal scope                                                                                                                          0
# Deal size                                                                                                                           0
# Target country                                                                                                                      0
# Current size under contract                                                                                                         1
# Current size in operation (production)                                                                                             99
# Current negotiation status                                                                                                          0
# Current implementation status                                                                                                       7
# Fully updated                                                                                                                      94
# Created at                                                                                                                          0
# Top parent companies                                                                                                               22
# Intended size (in ha)                                                                                                             412
# Size under contract (leased or purchased area, in ha)                                                                               1
# Size in operation (production, in ha)                                                                                              99
# Comment on land area                                                                                                              279
# Intention of investment                                                                                                             0
# Comment on intention of investment                                                                                                357
# Carbon offset project                                                                                                               0
# Comment on carbon offset project                                                                                                  423
# Nature of the deal                                                                                                                  0
# Comment on nature of the deal                                                                                                     377
# Negotiation status                                                                                                                  0
# Comment on negotiation status                                                                                                     343
# Implementation status                                                                                                               7
# Comment on implementation status                                                                                                  353
# Purchase price                                                                                                                    394
# Purchase price currency                                                                                                           394
# Purchase price area type                                                                                                          407
# Purchase price area                                                                                                               410
# Comment on purchase price                                                                                                         406
# Annual leasing fee                                                                                                                432
# Annual leasing fee currency                                                                                                       431
# Annual leasing fee type                                                                                                           433
# Annual leasing fee area                                                                                                           433
# Comment on leasing fees                                                                                                           405
# Contract farming                                                                                                                    0
# On leased / purchased                                                                                                               0
# On leased area/farmers/households                                                                                                 427
# Not on leased / purchased (out-grower)                                                                                              0
# Not on leased area/farmers/households (out-grower)                                                                                432
# Comment on contract farming                                                                                                       427
# Jobs created (total)                                                                                                                0
# Planned number of jobs (total)                                                                                                    389
# Planned employees (total)                                                                                                         401
# Planned daily/seasonal workers (total)                                                                                            434
# Current total number of jobs/employees/ daily/seasonal workers                                                                    350
# Comment on jobs created (total)                                                                                                   357
# Jobs created (foreign)                                                                                                              0
# Planned number of jobs (foreign)                                                                                                  435
# Planned employees (foreign)                                                                                                       435
# Planned daily/seasonal workers (foreign)                                                                                          435
# Current foreign number of jobs/employees/ daily/seasonal workers                                                                  434
# Comment on jobs created (foreign)                                                                                                 434
# Jobs created (domestic)                                                                                                             0
# Planned number of jobs (domestic)                                                                                                 432
# Planned employees (domestic)                                                                                                      435
# Planned daily/seasonal workers (domestic)                                                                                         435
# Current domestic number of jobs/employees/ daily/seasonal workers                                                                 432
# Comment on jobs created (domestic)                                                                                                421
# Actors involved in the negotiation / admission process                                                                            411
# Name of investment project                                                                                                        237
# Comment on investment chain                                                                                                       313
# Operating company: Investor ID                                                                                                      0
# Operating company: Name                                                                                                             0
# Operating company: Country of registration/origin                                                                                   0
# Operating company: Classification                                                                                                   6
# Operating company: Investor homepage                                                                                              329
# Operating company: Opencorporates link                                                                                            431
# Operating company: Comment                                                                                                        378
# Name of community                                                                                                                 393
# Name of indigenous people                                                                                                         406
# Comment on communities / indigenous peoples affected                                                                              359
# Recognition status of community land tenure                                                                                       400
# Comment on recognitions status of community land tenure                                                                           411
# Community consultation                                                                                                            378
# Comment on consultation of local community                                                                                        401
# Community reaction                                                                                                                355
# Comment on community reaction                                                                                                     383
# Presence of land conflicts                                                                                                          0
# Comment on presence of land conflicts                                                                                             351
# Displacement of people                                                                                                              0
# Number of people actually displaced                                                                                               431
# Number of households actually displaced                                                                                           433
# Number of people displaced out of their community land                                                                            434
# Number of people displaced staying on community land                                                                              435
# Number of households displaced "only" from their agricultural fields                                                              435
# Number of people facing displacement once project is fully implemented                                                            435
# Comment on displacement of people                                                                                                 413
# Negative impacts for local communities                                                                                            364
# Comment on negative impacts for local communities                                                                                 368
# Promised compensation (e.g. for damages or resettlements)                                                                         427
# Received compensation (e.g. for damages or resettlements)                                                                         433
# Promised benefits for local communities                                                                                           397
# Comment on promised benefits for local communities                                                                                410
# Materialized benefits for local communities                                                                                       388
# Comment on materialized benefits for local communities                                                                            384
# Presence of organizations and actions taken (e.g. farmer organizations, NGOs, etc.)                                               408
# Former land owner                                                                                                                 315
# Comment on former land owner                                                                                                      379
# Former land use                                                                                                                   312
# Comment on former land use                                                                                                        407
# Former land cover                                                                                                                 318
# Comment on former land cover                                                                                                      394
# Crops area/yield/export                                                                                                           154
# Comment on crops                                                                                                                  391
# Livestock area/yield/export                                                                                                       365
# Comment on livestock                                                                                                              431
# Mineral resources area/yield/export                                                                                               432
# Comment on mineral resources                                                                                                      434
# Contract farming crops                                                                                                            433
# Comment on contract farming crops                                                                                                 435
# Contract farming livestock                                                                                                        435
# Comment on contract farming livestock                                                                                             435
# Electricity generation                                                                                                            393
# Comment on electricity generation                                                                                                 402
# Carbon sequestration/offsetting                                                                                                   413
# Comment on carbon sequestration/offsetting                                                                                        424
# Has domestic use                                                                                                                    0
# Domestic use                                                                                                                      397
# Has export                                                                                                                          0
# Export                                                                                                                            393
# Country 1                                                                                                                         384
# Country 1 ratio                                                                                                                   402
# Country 2                                                                                                                         399
# Country 2 ratio                                                                                                                   403
# Country 3                                                                                                                         400
# Country 3 ratio                                                                                                                   403
# Comment on use of produce                                                                                                         390
# In country processing of produce                                                                                                    0
# Comment on in country processing of produce                                                                                       389
# Processing facilities / production infrastructure of the project (e.g. oil mill, ethanol distillery, biomass power plant etc.)    361
# In-country end products of the project                                                                                            354
# Water extraction envisaged                                                                                                          0
# Comment on water extraction envisaged                                                                                             417
# Source of water extraction                                                                                                        367
# Comment on source of water extraction                                                                                             374
# Comment on how much do investors pay for water                                                                                    427
# Water extraction amount                                                                                                           395
# Comment on how much water is extracted                                                                                            383
# Use of irrigation infrastructure                                                                                                    0
# Comment on use of irrigation infrastructure                                                                                       423
# Water footprint of the investment project                                                                                         435
# Comment on gender-related info                                                                                                    374
# Overall comment                                                                                                                   296
# Not public                                                                                                                          0
# Comment on not public                                                                                                             435
# dtype: int64

# %%
df_deals.sort_values(['Deal size'], ascending = False).head()
# Out:
#      Deal ID Is public     Deal scope  Deal size Target country  \
# 16       768       Yes  transnational  1300000.0         Brazil
# 175     4612       Yes  transnational   627072.0         Guyana
# 3        727       Yes  transnational   468000.0      Argentina
# 35       847       Yes  transnational   391853.0         Guyana
# 37       851       Yes  transnational   345961.0         Guyana
#
#      Current size under contract  Current size in operation (production)  \
# 16                     1300000.0                               1300000.0
# 175                     627072.0                                274053.0
# 3                       468000.0                                468000.0
# 35                      391853.0                                     NaN
# 37                      345961.0                                345961.0
#
#       Current negotiation status  Current implementation status  \
# 16   Concluded (Contract signed)      In operation (production)
# 175  Concluded (Contract signed)      In operation (production)
# 3    Concluded (Contract signed)      In operation (production)
# 35   Concluded (Contract signed)  Startup phase (no production)
# 37   Concluded (Contract signed)      In operation (production)
#
#                         Fully updated                 Created at  \
# 16   2025-06-05T14:41:34.347504+00:00  2013-02-15T16:00:40+00:00
# 175  2023-01-16T00:07:10.209000+00:00  2015-03-09T17:48:20+00:00
# 3    2023-07-03T22:20:20.959000+00:00  2013-02-15T16:00:35+00:00
# 35   2020-09-14T17:41:47.136275+00:00  2013-02-15T16:00:52+00:00
# 37   2022-09-01T15:16:59.010000+00:00  2013-02-15T16:00:52+00:00
#
#                                   Top parent companies  Intended size (in ha)  \
# 16   Royal Dutch Shell#3109#Netherlands|Cosan Indus...                    NaN
# 175  Bai Shan Lin International Forest Development ...                    NaN
# 3                               Walbrook#3987#Malaysia                    NaN
# 35                    Cafe Coffee Day (CCD)#2297#India                    NaN
# 37                    Cafe Coffee Day (CCD)#2297#India                    NaN
#
#     Size under contract (leased or purchased area, in ha)  \
# 16                    2015##86000|2021#current#1300000
# 175                                2014#current#627072
# 3                                  2011#current#468000
# 35                               2016#current#391853.0
# 37                                 2014#current#345961
#
#     Size in operation (production, in ha)  \
# 16      2015##860000|2021#current#1300000
# 175                   2014#current#274053
# 3                     2011#current#468000
# 35                                    NaN
# 37                    2014#current#345961
#
#                                   Comment on land area  \
# 16                                                 NaN
# 175  According to government announcements, Bai Sha...
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#                                Intention of investment  \
# 16   #current##Biomass for biofuels, Non-food agric...
# 175  #current##Timber plantation for wood and fiber...
# 3                        #current##Food crops, Tourism
# 35   #current##Timber plantation for wood and fiber...
# 37   #current##Timber plantation for wood and fiber...
#
#     Comment on intention of investment Carbon offset project  \
# 16                                 NaN               Unknown
# 175                                NaN               Unknown
# 3                                  NaN               Unknown
# 35                                 NaN               Unknown
# 37                  Logging concession               Unknown
#
#     Comment on carbon offset project Nature of the deal  \
# 16                               NaN  Outright purchase
# 175                              NaN              Lease
# 3                                NaN  Outright purchase
# 35                               NaN              Lease
# 37                               NaN              Lease
#
#                          Comment on nature of the deal  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37   The Timber Sales Agreement (TSA) was originall...
#
#                                     Negotiation status  \
# 16            2010#current#Concluded (Contract signed)
# 175  2007##Concluded (Contract signed)|2009##Conclu...
# 3             2001#current#Concluded (Contract signed)
# 35            2010#current#Concluded (Contract signed)
# 37            2010#current#Concluded (Contract signed)
#
#                          Comment on negotiation status  \
# 16                                                 NaN
# 175  TSA 01/2007 granted to the joint venture with ...
# 3                                                  NaN
# 35                                                 NaN
# 37   The Timber Sales Agreement (TSA) was originall...
#
#                           Implementation status  \
# 16       2010#current#In operation (production)
# 175      2011#current#In operation (production)
# 3        2001#current#In operation (production)
# 35   2015#current#Startup phase (no production)
# 37       2011#current#In operation (production)
#
#                       Comment on implementation status  Purchase price  \
# 16                                                 NaN             NaN
# 175                                                NaN             NaN
# 3                                                  NaN       5000000.0
# 35                                                 NaN             NaN
# 37   They are exporting unprocessed logs from the land             NaN
#
#     Purchase price currency Purchase price area type  Purchase price area  \
# 16                      NaN                      NaN                  NaN
# 175                     NaN                      NaN                  NaN
# 3             US Dollar ($)                      NaN                  NaN
# 35                      NaN                      NaN                  NaN
# 37                      NaN                      NaN                  NaN
#
#                              Comment on purchase price  Annual leasing fee  \
# 16                                                 NaN                 NaN
# 175                                                NaN                 NaN
# 3    La empresa pagó 5 millones de dólares por las ...                 NaN
# 35                                                 NaN                 NaN
# 37   Vaitarna paid 3 million USD for the TSA (in ad...                 NaN
#
#     Annual leasing fee currency Annual leasing fee type  \
# 16                          NaN                     NaN
# 175                         NaN                     NaN
# 3                           NaN                     NaN
# 35                          NaN                     NaN
# 37                          NaN                     NaN
#
#      Annual leasing fee area Comment on leasing fees Contract farming  \
# 16                       NaN                     NaN          Unknown
# 175                      NaN                     NaN          Unknown
# 3                        NaN                     NaN          Unknown
# 35                       NaN                     NaN          Unknown
# 37                       NaN                     NaN          Unknown
#
#     On leased / purchased On leased area/farmers/households  \
# 16                Unknown                               NaN
# 175               Unknown                               NaN
# 3                 Unknown                               NaN
# 35                Unknown                               NaN
# 37                Unknown                               NaN
#
#     Not on leased / purchased (out-grower)  \
# 16                                 Unknown
# 175                                Unknown
# 3                                  Unknown
# 35                                 Unknown
# 37                                 Unknown
#
#     Not on leased area/farmers/households (out-grower)  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Comment on contract farming Jobs created (total)  \
# 16                          NaN              Unknown
# 175                         NaN              Unknown
# 3                           NaN                  Yes
# 35                          NaN              Unknown
# 37                          NaN              Unknown
#
#      Planned number of jobs (total)  Planned employees (total)  \
# 16                              NaN                        NaN
# 175                             NaN                        NaN
# 3                             200.0                        NaN
# 35                              NaN                        NaN
# 37                              NaN                        NaN
#
#      Planned daily/seasonal workers (total)  \
# 16                                      NaN
# 175                                     NaN
# 3                                       NaN
# 35                                      NaN
# 37                                      NaN
#
#     Current total number of jobs/employees/ daily/seasonal workers  \
# 16                                2012#current#40000##
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#                        Comment on jobs created (total) Jobs created (foreign)  \
# 16                                                 NaN                Unknown
# 175                                                NaN                Unknown
# 3    En sus inicios, la empresa planeaba crear 200 ...                Unknown
# 35                                                 NaN                Unknown
# 37                                                 NaN                Unknown
#
#      Planned number of jobs (foreign)  Planned employees (foreign)  \
# 16                                NaN                          NaN
# 175                               NaN                          NaN
# 3                                 NaN                          NaN
# 35                                NaN                          NaN
# 37                                NaN                          NaN
#
#      Planned daily/seasonal workers (foreign)  \
# 16                                        NaN
# 175                                       NaN
# 3                                         NaN
# 35                                        NaN
# 37                                        NaN
#
#     Current foreign number of jobs/employees/ daily/seasonal workers  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Comment on jobs created (foreign) Jobs created (domestic)  \
# 16                                NaN                 Unknown
# 175                               NaN                 Unknown
# 3                                 NaN                 Unknown
# 35                                NaN                 Unknown
# 37                                NaN                 Unknown
#
#      Planned number of jobs (domestic)  Planned employees (domestic)  \
# 16                                 NaN                           NaN
# 175                                NaN                           NaN
# 3                                  NaN                           NaN
# 35                                 NaN                           NaN
# 37                                 NaN                           NaN
#
#      Planned daily/seasonal workers (domestic)  \
# 16                                         NaN
# 175                                        NaN
# 3                                          NaN
# 35                                         NaN
# 37                                         NaN
#
#     Current domestic number of jobs/employees/ daily/seasonal workers  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Comment on jobs created (domestic)  \
# 16                                 NaN
# 175                                NaN
# 3                                  NaN
# 35                                 NaN
# 37                                 NaN
#
#     Actors involved in the negotiation / admission process  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Name of investment project  \
# 16                         NaN
# 175                        NaN
# 3                          NaN
# 35                         NaN
# 37                         NaN
#
#                            Comment on investment chain  \
# 16                                                 NaN
# 175  Bai Shan Lin has joint ventures with Sherwood ...
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#      Operating company: Investor ID                Operating company: Name  \
# 16                            35396                                 Raizen
# 175                           38651                      Bai Shan Lin Inc.
# 3                             35369                  Nieves de Mendoza SA.
# 35                            37532  Vaitarna Holdings Private Inc. (VHPI)
# 37                            37532  Vaitarna Holdings Private Inc. (VHPI)
#
#     Operating company: Country of registration/origin  \
# 16                                             Brazil
# 175                                            Guyana
# 3                                           Argentina
# 35                                             Guyana
# 37                                             Guyana
#
#     Operating company: Classification Operating company: Investor homepage  \
# 16                    Private company                                  NaN
# 175                   Private company                                  NaN
# 3                     Private company                                  NaN
# 35                    Private company                                  NaN
# 37                    Private company                                  NaN
#
#     Operating company: Opencorporates link Operating company: Comment  \
# 16                                     NaN                        NaN
# 175                                    NaN                        NaN
# 3                                      NaN                        NaN
# 35                                     NaN                        NaN
# 37                                     NaN                        NaN
#
#     Name of community Name of indigenous people  \
# 16                NaN                  Guaraní#
# 175               NaN                       NaN
# 3                 NaN                       NaN
# 35                NaN                       NaN
# 37                NaN                       NaN
#
#     Comment on communities / indigenous peoples affected  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Recognition status of community land tenure  \
# 16                                          NaN
# 175                                         NaN
# 3                                           NaN
# 35                                          NaN
# 37                                          NaN
#
#     Comment on recognitions status of community land tenure  \
# 16   Muchos guaraníes viven en condiciones deplorab...
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Community consultation Comment on consultation of local community  \
# 16                     NaN                                        NaN
# 175          Not consulted                                        NaN
# 3                      NaN                                        NaN
# 35                     NaN                                        NaN
# 37           Not consulted                                        NaN
#
#     Community reaction                      Comment on community reaction  \
# 16                 NaN  Indígenas guaraníes denunciaron que Raizen com...
# 175                NaN  Media reports claim that the area exploited by...
# 3                  NaN                                                NaN
# 35                 NaN  Reports critizice the delay in setting up a wo...
# 37             Consent  There are reports critizicing the delay in set...
#
#     Presence of land conflicts  \
# 16                     Unknown
# 175                    Unknown
# 3                          Yes
# 35                     Unknown
# 37                     Unknown
#
#                  Comment on presence of land conflicts Displacement of people  \
# 16   Existen conflictos violentos entre agricultore...                Unknown
# 175                                                NaN                Unknown
# 3    La familia Gutiérrez de puesto “El álamo” resi...                Unknown
# 35                                                 NaN                Unknown
# 37                                                 NaN                Unknown
#
#      Number of people actually displaced  \
# 16                                   NaN
# 175                                  NaN
# 3                                    NaN
# 35                                   NaN
# 37                                   NaN
#
#      Number of households actually displaced  \
# 16                                       NaN
# 175                                      NaN
# 3                                        NaN
# 35                                       NaN
# 37                                       NaN
#
#      Number of people displaced out of their community land  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#      Number of people displaced staying on community land  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#      Number of households displaced "only" from their agricultural fields  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#      Number of people facing displacement once project is fully implemented  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#                      Comment on displacement of people  \
# 16                                                 NaN
# 175                                                NaN
# 3    The town Las Juntas is in the lands purchased ...
# 35                                                 NaN
# 37                                                 NaN
#
#     Negative impacts for local communities  \
# 16                                     NaN
# 175                                    NaN
# 3                                      NaN
# 35                                     NaN
# 37                                     NaN
#
#     Comment on negative impacts for local communities  \
# 16                                                NaN
# 175                                               NaN
# 3                                                 NaN
# 35                                                NaN
# 37                                                NaN
#
#     Promised compensation (e.g. for damages or resettlements)  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Received compensation (e.g. for damages or resettlements)  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Promised benefits for local communities  \
# 16                                      NaN
# 175                                     NaN
# 3                                       NaN
# 35                                      NaN
# 37                                    Other
#
#     Comment on promised benefits for local communities  \
# 16   Raizen se comprometió a realizar un programa d...
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                             Trabajo
#
#     Materialized benefits for local communities  \
# 16                                          NaN
# 175                                       Roads
# 3                                           NaN
# 35                                          NaN
# 37                                          NaN
#
#     Comment on materialized benefits for local communities  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     Presence of organizations and actions taken (e.g. farmer organizations, NGOs, etc.)  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#                     Former land owner  \
# 16                                NaN
# 175  State|Private (large-scale farm)
# 3                                 NaN
# 35                              State
# 37                              State
#
#                           Comment on former land owner Former land use  \
# 16                                                 NaN             NaN
# 175  Partly, the concessions were taken over from f...             NaN
# 3                                                  NaN             NaN
# 35                                                 NaN        Forestry
# 37                                                 NaN        Forestry
#
#     Comment on former land use Former land cover Comment on former land cover  \
# 16                         NaN               NaN                          NaN
# 175                        NaN       Forest land                          NaN
# 3                          NaN               NaN                          NaN
# 35                         NaN       Forest land                          NaN
# 37                         NaN       Forest land                          NaN
#
#                                Crops area/yield/export Comment on crops  \
# 16                              #current####Sugar Cane              NaN
# 175                                                NaN              NaN
# 3    #current####Potatoes, Seeds Production (unspec...              NaN
# 35                                                 NaN              NaN
# 37                                                 NaN              NaN
#
#     Livestock area/yield/export Comment on livestock  \
# 16                          NaN                  NaN
# 175                         NaN                  NaN
# 3             #current####Goats                  NaN
# 35                          NaN                  NaN
# 37                          NaN                  NaN
#
#     Mineral resources area/yield/export Comment on mineral resources  \
# 16                                  NaN                          NaN
# 175                                 NaN                          NaN
# 3                                   NaN                          NaN
# 35                                  NaN                          NaN
# 37                                  NaN                          NaN
#
#     Contract farming crops  Comment on contract farming crops  \
# 16                     NaN                                NaN
# 175                    NaN                                NaN
# 3                      NaN                                NaN
# 35                     NaN                                NaN
# 37                     NaN                                NaN
#
#      Contract farming livestock  Comment on contract farming livestock  \
# 16                          NaN                                    NaN
# 175                         NaN                                    NaN
# 3                           NaN                                    NaN
# 35                          NaN                                    NaN
# 37                          NaN                                    NaN
#
#     Electricity generation Comment on electricity generation  \
# 16                     NaN                               NaN
# 175                    NaN                               NaN
# 3                      NaN                               NaN
# 35                     NaN                               NaN
# 37                     NaN                               NaN
#
#     Carbon sequestration/offsetting  \
# 16                              NaN
# 175                             NaN
# 3                               NaN
# 35                              NaN
# 37                              NaN
#
#     Comment on carbon sequestration/offsetting Has domestic use  Domestic use  \
# 16                                         NaN          Unknown           NaN
# 175                                        NaN          Unknown           NaN
# 3                                          NaN          Unknown           NaN
# 35                                         NaN          Unknown           NaN
# 37                                         NaN          Unknown           NaN
#
#     Has export  Export Country 1  Country 1 ratio Country 2  Country 2 ratio  \
# 16     Unknown     NaN       NaN              NaN       NaN              NaN
# 175        Yes   100.0     China              NaN       NaN              NaN
# 3          Yes     NaN     India              NaN       NaN              NaN
# 35         Yes   100.0     India              NaN       NaN              NaN
# 37         Yes   100.0     India              NaN       NaN              NaN
#
#     Country 3  Country 3 ratio Comment on use of produce  \
# 16        NaN              NaN                       NaN
# 175       NaN              NaN                       NaN
# 3         NaN              NaN                       NaN
# 35        NaN              NaN                       NaN
# 37        NaN              NaN                       NaN
#
#     In country processing of produce  \
# 16                           Unknown
# 175                               No
# 3                            Unknown
# 35                                No
# 37                                No
#
#     Comment on in country processing of produce  \
# 16                                          NaN
# 175                                         NaN
# 3                                           NaN
# 35            Processing is being done in India
# 37     The processing is taking place in India.
#
#     Processing facilities / production infrastructure of the project (e.g. oil mill, ethanol distillery, biomass power plant etc.)  \
# 16                                                 NaN
# 175                                                NaN
# 3                                                  NaN
# 35                                                 NaN
# 37                                                 NaN
#
#     In-country end products of the project Water extraction envisaged  \
# 16                                     NaN                    Unknown
# 175                                    NaN                    Unknown
# 3                                      NaN                    Unknown
# 35                                     NaN                    Unknown
# 37                                     NaN                    Unknown
#
#     Comment on water extraction envisaged Source of water extraction  \
# 16                                    NaN                        NaN
# 175                                   NaN                        NaN
# 3                                     NaN                        NaN
# 35                                    NaN                        NaN
# 37                                    NaN                        NaN
#
#     Comment on source of water extraction  \
# 16                                    NaN
# 175                                   NaN
# 3                                     NaN
# 35                                    NaN
# 37                                    NaN
#
#     Comment on how much do investors pay for water  Water extraction amount  \
# 16                                             NaN                      NaN
# 175                                            NaN                      NaN
# 3                                              NaN                      NaN
# 35                                             NaN                      NaN
# 37                                             NaN                      NaN
#
#     Comment on how much water is extracted Use of irrigation infrastructure  \
# 16                                     NaN                          Unknown
# 175                                    NaN                          Unknown
# 3                                      NaN                          Unknown
# 35                                     NaN                          Unknown
# 37                                     NaN                          Unknown
#
#     Comment on use of irrigation infrastructure  \
# 16                                          NaN
# 175                                         NaN
# 3                                           NaN
# 35                                          NaN
# 37                                          NaN
#
#      Water footprint of the investment project Comment on gender-related info  \
# 16                                         NaN                            NaN
# 175                                        NaN                            NaN
# 3                                          NaN                            NaN
# 35                                         NaN                            NaN
# 37                                         NaN                            NaN
#
#                                        Overall comment  Not public  \
# 16                                                 NaN       False
# 175  Bai Shan Lin holds several TSAs (274053 ha), S...       False
# 3    Import of error check - Coordinator's overview...       False
# 35   The State Forest Exploratory Permit (SFEP) 03/...       False
# 37   The Timber Sales Agreement (TSA), a 25 year co...       False
#
#      Comment on not public
# 16                     NaN
# 175                    NaN
# 3                      NaN
# 35                     NaN
# 37                     NaN

# %%
#Grouping countries and accumulating the deal sizes to get a national value of deals
dealsize_per_country = df_deals.groupby(['Target country'], group_keys = True)[['Deal size']].sum()
dealsize_per_country.head()
# Out:
#                  Deal size
# Target country
# Argentina       1426385.86
# Belize            51984.00
# Bolivia           34450.00
# Brazil          3765308.87
# Chile            329118.01

# %%
# operating_companies = df_deals['Operating company: Name']
# operating_companies
# operating_countries = df_deals['Operating company: Country of registration/origin']
# operating_countries

# %%
# df_deals.info()
# df_deals.shape()

# %%
# getting contracts data

df_contracts = pd.read_csv(
    "export\contracts.csv",
    sep=";",         
    engine="python",  
    encoding="utf-8",
)

df_contracts.head()
# Out:
#          ID  Deal ID Contract number Contract date Contract expiration date  \
# 0  1w4V2aI9      724             NaN           NaN                      NaN
# 1  tGSS5q4E      778             NaN           NaN                      NaN
# 2  0fXI63az      847             NaN           NaN                      NaN
# 3  d24WOchE      849             NaN           NaN                      NaN
# 4  PDMXavWg      851             NaN           NaN                      NaN
#
#    Duration of the agreement Comment on contract
# 0                        5.0                 NaN
# 1                       25.0                 NaN
# 2                       30.0                 NaN
# 3                       90.0                 NaN
# 4                       25.0                 NaN

# %%
df_contracts_clean = df_contracts[['ID', 'Deal ID', 'Duration of the agreement']]

# %%
df_contracts_clean.head()
# Out:
#          ID  Deal ID  Duration of the agreement
# 0  1w4V2aI9      724                        5.0
# 1  tGSS5q4E      778                       25.0
# 2  0fXI63az      847                       30.0
# 3  d24WOchE      849                       90.0
# 4  PDMXavWg      851                       25.0

# %%
df_investors = pd.read_csv(
    "export\investors.csv",
    sep=";",         
    engine="python",  
    encoding="utf-8",
)

df_investors.head()
# Out:
#    Investor ID                            Name  \
# 0            2        Government of Bangladesh
# 1           11      China Asean Resources Ltd.
# 2           12          Agro Forestry Research
# 3           14  Amira Nature Foods Ltd (ANFIF)
# 4           18                       Bigimexco
#
#                    Country of registration/origin  \
# 0                                      Bangladesh
# 1  China, Hong Kong Special Administrative Region
# 2                                           China
# 3                            United Arab Emirates
# 4                                         Vietnam
#
#                       Classification       Investor homepage  \
# 0  State-/government (owned) company                     NaN
# 1      Stock-exchange listed company                     NaN
# 2                                NaN                     NaN
# 3      Stock-exchange listed company  https://www.amira.net/
# 4                    Private company                     NaN
#
#   Opencorporates link                                            Comment  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN  Amira Nature Foods Ltd is a food company prima...
# 4                 NaN                                                NaN
#
#    Action comment
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
investor_countries = df_investors.groupby(['Country of registration/origin'], group_keys = True)['Name'].count()
investor_countries
# Out:
# Country of registration/origin
# Afghanistan                                               1
# Albania                                                   6
# Algeria                                                  21
# Angola                                                   58
# Argentina                                               428
# Armenia                                                   1
# Aruba                                                     1
# Australia                                                88
# Austria                                                  18
# Bahamas                                                   1
# Bahrain                                                   6
# Bangladesh                                               41
# Barbados                                                  3
# Belarus                                                   7
# Belgium                                                  25
# Belize                                                    9
# Benin                                                    14
# Bermuda                                                   8
# Bolivia                                                  24
# Bosnia and Herzegovina                                   17
# Botswana                                                  9
# Brazil                                                  302
# British Virgin Islands                                   34
# Bulgaria                                                 66
# Burkina Faso                                             28
# Burundi                                                   3
# Cambodia                                                325
# Cameroon                                                 98
# Canada                                                  182
# Cape Verde                                                1
# Cayman Islands                                           13
# Central African Republic                                 15
# Chad                                                      3
# Chile                                                    82
# China                                                   487
# China, Hong Kong Special Administrative Region           43
# Colombia                                                183
# Congo, Dem. Rep.                                         97
# Congo, Rep.                                              37
# Costa Rica                                               16
# Croatia                                                   5
# Cuba                                                      2
# Cyprus                                                   98
# Czech Republic                                            9
# Côte d'Ivoire                                            44
# Denmark                                                  40
# Djibouti                                                  3
# Dominican Republic                                        5
# Ecuador                                                  37
# Egypt, Arab Rep.                                         44
# El Salvador                                               1
# Equatorial Guinea                                         1
# Eritrea                                                   3
# Estonia                                                   5
# Ethiopia                                                285
# Finland                                                  11
# France                                                  114
# Gabon                                                    24
# Gambia, The                                               6
# Georgia                                                  31
# Germany                                                 115
# Ghana                                                   164
# Gibraltar                                                 1
# Greece                                                    4
# Guatemala                                                24
# Guernsey                                                  8
# Guinea                                                   23
# Guinea-Bissau                                             3
# Guyana                                                    7
# Honduras                                                 14
# Hungary                                                   5
# Iceland                                                   1
# India                                                   447
# Indonesia                                               544
# Iran, Islamic Rep.                                        9
# Iraq                                                      6
# Ireland                                                   7
# Isle of Man                                               2
# Israel                                                   23
# Italy                                                    61
# Jamaica                                                   1
# Japan                                                    77
# Jersey                                                    3
# Jordan                                                    9
# Kazakhstan                                               60
# Kenya                                                   115
# Korea, Dem. People's Rep.                                10
# Kuwait                                                    6
# Kyrgyz Republic                                           2
# Lao PDR                                                 201
# Latvia                                                    1
# Lebanon                                                  17
# Lesotho                                                   4
# Liberia                                                  65
# Libya                                                     6
# Liechtenstein                                             8
# Lithuania                                                 9
# Luxembourg                                               34
# Madagascar                                               76
# Malawi                                                   44
# Malaysia                                                209
# Maldives                                                  2
# Mali                                                     59
# Malta                                                     2
# Mauritania                                                8
# Mauritius                                                41
# Mexico                                                   63
# Moldova                                                  14
# Monaco                                                    2
# Mongolia                                                 42
# Morocco                                                  23
# Mozambique                                              230
# Myanmar                                                 128
# Namibia                                                  48
# Nepal                                                    57
# Netherlands                                             122
# New Zealand                                              12
# Nicaragua                                                41
# Niger                                                    16
# Nigeria                                                 179
# North Macedonia                                           4
# Norway                                                   30
# Pakistan                                                 44
# Panama                                                   23
# Papua New Guinea                                         60
# Paraguay                                                 53
# Peru                                                    159
# Philippines                                             413
# Poland                                                    3
# Portugal                                                 24
# Qatar                                                    11
# Republic of Korea                                        67
# Romania                                                 192
# Russian Federation                                      306
# Rwanda                                                   27
# Réunion                                                   1
# Saudi Arabia                                             52
# Senegal                                                 168
# Serbia                                                   56
# Seychelles                                                2
# Sierra Leone                                             68
# Singapore                                                95
# Slovenia                                                  1
# Solomon Islands                                           1
# South Africa                                            302
# South Sudan                                              33
# Spain                                                    54
# Sri Lanka                                                37
# Sudan                                                    66
# Suriname                                                  5
# Swaziland                                                23
# Sweden                                                   26
# Switzerland                                              49
# Syrian Arab Republic                                      2
# São Tomé and Principe                                     2
# Tajikistan                                                6
# Tanzania                                                170
# Thailand                                                111
# Timor-Leste                                               5
# Togo                                                      3
# Tunisia                                                  11
# Türkiye                                                  54
# Uganda                                                  103
# Ukraine                                                 526
# United Arab Emirates                                     73
# United Kingdom of Great Britain and Northern Ireland    234
# United States Virgin Islands                              3
# United States of America                                273
# Uruguay                                                  47
# Uzbekistan                                               78
# Venezuela, RB                                             3
# Vietnam                                                 263
# Yemen, Rep.                                               1
# Zambia                                                  114
# Zimbabwe                                                 78
# Name: Name, dtype: int64

# %%
df_locations = pd.read_csv(
    "export\locations.csv",
    sep=";",         
    engine="python",  
    encoding="utf-8",
)

df_locations.head()
# Out:
#          ID  Deal ID Spatial accuracy level  \
# 0  h_Ikeox-      710  Administrative region
# 1  Ph2RbCSj      717  Administrative region
# 2  UuEBndEN      724  Administrative region
# 3  m3B1vgMY      727            Coordinates
# 4  XBYgadvF      727            Coordinates
#
#                                 Location                Point Facility name  \
# 0   Punta Colorada, Río Negro, Argentina  -41.83692,-65.19556           NaN
# 1                   Río Negro, Argentina  -40.73443,-66.61765           NaN
# 2       Buenos Aires Province, Argentina  -37.20173,-59.84107           NaN
# 3  Malargüe, Mendoza Province, Argentina  -35.48446,-69.57975           NaN
# 4         Los Molles, Mendoza, Argentina  -35.16562,-69.93887      El Álamo
#
#   Location description                                Comment on location
# 0                  NaN  Río Negro, Between the land of Solari Yrigoyen...
# 1                  NaN                               Province "Río Negro"
# 2                  NaN                                                NaN
# 3                  NaN  Los establecimientos de la empresa en Mendoza ...
# 4                  NaN  Es uno de los campos de la empresa, tiene 1500...

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      548 non-null    object
#  1   Deal ID                 548 non-null    int64
#  2   Spatial accuracy level  545 non-null    object
#  3   Location                472 non-null    object
#  4   Point                   535 non-null    object
#  5   Facility name           281 non-null    object
#  6   Location description    81 non-null     object
#  7   Comment on location     131 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 34.4+ KB

# %%
df_involvements = pd.read_csv(
    "export\involvements.csv",
    sep=";",         
    engine="python",  
    encoding="utf-8",
)

df_involvements.head()
# Out:
#    Involvement ID  Investor ID Downstream  \
# 0              10                   34793
# 1              11                   34795
# 2              13                   34801
# 3              16                   34806
# 4              17                   34808
#
#                             Investor Name Downstream  Investor ID Upstream  \
# 0                   Unknown (Agro Forestry Research)                    12
# 1                   Amira Pure Foods Private Limited                    14
# 2  Unknown (Bon Bon World Investments and Consult...                    20
# 3               Carmadeno Venture (Cambodia) Limited                    25
# 4                      Central First Company Limited                    27
#
#                               Investor Name Upstream   Relation type  \
# 0                             Agro Forestry Research  Parent company
# 1                     Amira Nature Foods Ltd (ANFIF)  Parent company
# 2  Bon Bon World Investments and Consulting Group...  Parent company
# 3                          Carmadeno Venture Limited  Parent company
# 4                              Central First Company  Parent company
#
#   Investment type  Ownership share  Loan amount Loan currency Loan date  \
# 0             NaN              NaN          NaN           NaN       NaN
# 1   Shares/Equity            100.0          NaN           NaN       NaN
# 2             NaN              NaN          NaN           NaN       NaN
# 3             NaN              NaN          NaN           NaN       NaN
# 4             NaN              NaN          NaN           NaN       NaN
#
#   Comment
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df_involvements.iloc[:, 7]
# Out:
# 0          NaN
# 1       100.00
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 7525     99.37
# 7526       NaN
# 7527       NaN
# 7528     72.00
# 7529     28.00
# Name: Ownership share, Length: 7530, dtype: float64

# %%
df_involvements.iloc[:, 6]
# Out:
# 0                 NaN
# 1       Shares/Equity
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 7525    Shares/Equity
# 7526              NaN
# 7527              NaN
# 7528    Shares/Equity
# 7529    Shares/Equity
# Name: Investment type, Length: 7530, dtype: object
